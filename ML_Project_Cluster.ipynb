# %% [markdown]
# <a href="https://colab.research.google.com/github/JOTHEESS/MachineLearning_Projects/blob/main/ML_Project_Cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-49822bc5-06d8-40f8-9fd4-6393529dfca1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49822bc5-06d8-40f8-9fd4-6393529dfca1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
#  SCALER face a challenge in understanding the diverse backgrounds of their learners, such as their current roles, companies, and experience levels. By clustering similar learners, Scaler can provide a more personalized learning experience, tailored content recommendations, and specialized mentorship.

# %%
data = pd.read_csv('scaler_clustering.csv')

# %%
data.head()
# Out:
#    Unnamed: 0               company_hash  \
# 0           0             atrgxnnt xzaxv
# 1           1  qtrxvzwt xzegwgbb rxbxnta
# 2           2              ojzwnvwnxw vx
# 3           3                  ngpgutaxv
# 4           4                 qxen sqghu
#
#                                           email_hash  orgyear      ctc  \
# 0  6de0a4417d18ab14334c3f43397fc13b30c35149d70c05...   2016.0  1100000
# 1  b0aaf1ac138b53cb6e039ba2c3d6604a250d02d5145c10...   2018.0   449999
# 2  4860c670bcd48fb96c02a4b0ae3608ae6fdd98176112e9...   2015.0  2000000
# 3  effdede7a2e7c2af664c8a31d9346385016128d66bbc58...   2017.0   700000
# 4  6ff54e709262f55cb999a1c1db8436cb2055d8f79ab520...   2017.0  1400000
#
#          job_position  ctc_updated_year
# 0               Other            2020.0
# 1  FullStack Engineer            2019.0
# 2    Backend Engineer            2020.0
# 3    Backend Engineer            2019.0
# 4  FullStack Engineer            2019.0

# %%
# Calculate the percentage distribution of values in the 'job_position' column
percentage_distribution = data['job_position'].value_counts(normalize=True) * 100

# Create a DataFrame from the percentage distribution and select the top 15 values
top_15_job_positions = pd.DataFrame(percentage_distribution)[0:15]

# %%
top_15_job_positions
# Out:
#                         proportion
# job_position
# Backend Engineer         28.414851
# FullStack Engineer       16.125497
# Other                    11.789612
# Frontend Engineer         6.796104
# Engineering Leadership    4.482023
# QA Engineer               4.297392
# Data Scientist            3.502111
# Android Engineer          3.494934
# SDET                      3.240496
# Devops Engineer           3.008892
# Support Engineer          2.350616
# Data Analyst              1.895889
# iOS Engineer              1.791504
# Engineering Intern        1.756275
# Product Designer          0.857260

# %% [markdown]
# Hashing of email, Null Imputation & Dropping
# of unnecessary columns

# %%
data.drop(columns=['email_hash'],inplace=True)

# %%
import hashlib

data['company'] = data['company_hash'].apply(lambda x: reverse_lookup(x) if not pd.isnull(x) else 'Unknown')

# Drop the original 'company_hash' column
data.drop(columns=['company_hash'], inplace=True)

print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-66cc02cbd2ca> in <cell line: 3>()
#       1 import hashlib
#       2
# ----> 3 data['company'] = data['company_hash'].apply(lambda x: reverse_lookup(x) if not pd.isnull(x) else 'Unknown')
#       4
#       5 # Drop the original 'company_hash' column
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4628         dtype: float64
#    4629         """
# -> 4630         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4631
#    4632     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1023
#    1024         # self.f is Callable
# -> 1025         return self.apply_standard()
#    1026
#    1027     def agg(self):
#
# ...

# %%
data.isnull().sum()/len(data)*100
# Out:
# Unnamed: 0           0.000000
# orgyear              0.041779
# ctc                  0.000000
# job_position        25.535967
# ctc_updated_year     0.000000
# company              0.000000
# dtype: float64

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (205843, 6)

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)

# %% [markdown]
# Data Preprocessing
# Removing special characters from company & Job Position

# %%
import re
def remove_special (string):
 new_string=re.sub('[^A-Za-z0-9 ]+', '', string)
 return new_string

# %%
#what happens here
mystring='\tAirtel X Labs'
re.sub('[^A-Za-z0-9 ]+', '', mystring)
# Out:
# 'Airtel X Labs'

# %%
data.company = data.company.apply(lambda x: remove_special(str(x)))
data.company = data.company.apply(lambda x: x.lower())
data.company = data.company.apply(lambda x: x.strip())
data.company
# Out:
# 0         cdb9c466505f63c8e6f40e9715f7773c7641fd299ca765...
# 1         b9f8e710b2b287209c02f70669edd3e1a1fdc278b5f301...
# 2         6da851a4fb1e6baa11caae9409bdefc9d84c7f5625f424...
# 3         edd16e6c41b1ec4487e9d8cc3c3046b74246806400f947...
# 4         2dc489f09831a117b7f07fd57c6e45f0da66e1e0b3cbd1...
#                                 ...
# 205838    f288b5ba1e6c512cedc8ea0b82e92fff53093da1765cf0...
# 205839    9369ba1f655f039771d79658b87555ef97f14572e6d8be...
# 205840    ab4ea19b41ab75cc4340ec9b7eeb0c22d92b25e12eb751...
# 205841    f6ef41c5ed805613b8139b60d63a511ee842b64354fda9...
# 205842    714ed4bf3327dab063c0db4a15c8be8ab3b3700183f682...
# Name: company, Length: 205843, dtype: object
